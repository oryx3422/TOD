# %% [markdown]
# # Numpy

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 1: Библиотека Numpy"
# * https://numpy.org/doc/stable/user/index.html
# * https://numpy.org/doc/stable/reference/index.html

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Сгенерировать двухмерный массив `arr` размерности (4, 7), состоящий из случайных действительных чисел, равномерно распределенных в диапазоне от 0 до 20. Нормализовать значения массива с помощью преобразования вида  $𝑎𝑥+𝑏$  так, что после нормализации максимальный элемент масcива будет равен 1.0, минимальный 0.0

# %%
import numpy as np

arr = np.random.uniform(0, 20, size=(4, 7))

minarr = arr.min()
maxarr = arr.max()

a = 1 / (maxarr - minarr)
b = -a * minarr

normalarr = a * arr + b

print(f'максимальный элемент после нормализации: {normalarr.max()}')
print(f'минимальный элемент после нормализации: {normalarr.min()}')

print('нормализованный массив:')
print(normalarr)
# Out:
# максимальный элемент после нормализации: 0.9999999999999999
# минимальный элемент после нормализации: 0.0
# нормализованный массив:
# [[0.43980499 1.         0.72361722 0.9973796  0.         0.19431158
#   0.04421313]
#  [0.50786243 0.0555961  0.76816306 0.04402559 0.33182561 0.61150675
#   0.15112275]
#  [0.106015   0.1959051  0.78505052 0.3857872  0.03747964 0.05291538
#   0.2819537 ]
#  [0.4815313  0.98687236 0.90351227 0.80122093 0.75403366 0.31564464
#   0.19099529]]

# %% [markdown]
# 2. Создать матрицу 8 на 10 из случайных целых (используя модуль `numpy.random`) чисел из диапозона от 0 до 10 и найти в ней строку (ее индекс и вывести саму строку), в которой сумма значений минимальна.

# %%
import numpy as np

mtrx = np.random.uniform(0, 11, size=(8, 10))
mtrx = mtrx.astype(int)

idmin = np.argmin(mtrx.sum(axis=1))  # для нахождения индекса строки

print(f'строка {idmin+1} имеет минимальную сумму значений:')
print(mtrx[idmin])
print()
print(mtrx)
# Out:
# строка 7 имеет минимальную сумму значений:
# [8 1 6 9 1 3 2 3 0 9]
#
# [[ 1  2  2  0  8  6  8  5  5 10]
#  [ 7  9  0  1  5  5  9  1  8  8]
#  [ 3  8  6  7  6  7  0  5  4  1]
#  [ 7  1  3  5  6  5  4  6  9  9]
#  [10 10  0  3  9  2  4  3  1  1]
#  [ 6  3  7  5 10  3 10  1 10  5]
#  [ 8  1  6  9  1  3  2  3  0  9]
#  [ 5  8  8  8 10  8 10  2  8  0]]

# %% [markdown]
# 3. Найти евклидово расстояние между двумя одномерными векторами одинаковой размерности.

# %% [markdown]
# ![Screenshot_11.png](data:image/png;base64,...![Screenshot_12.png](data:image/png;base64,...))

# %%
import numpy as np

x = np.array([3, 2, 3, 4, 3])
y = np.array([6, 2, 4, 5, 5])

d = np.sqrt(np.sum((x - y) ** 2))

print(f'евклидово расстояние = {d}')
# Out:
# евклидово расстояние = 3.872983346207417

# %% [markdown]
# 4. Решить матричное уравнение `A*X*B=-C` - найти матрицу `X`. Где `A = [[-1, 2, 4], [-3, 1, 2], [-3, 0, 1]]`, `B=[[3, -1], [2, 1]]`, `C=[[7, 21], [11, 8], [8, 4]]`.

# %%
import numpy as np

a = np.array([[-1, 2, 4], [-3, 1, 2], [-3, 0, 1]])
b = np.array([[3, -1], [2, 1]])
c = np.array([[7, 21], [11, 8], [8, 4]])

reversea = np.linalg.inv(a)
reverseb = np.linalg.inv(b)

x = -np.dot(np.dot(reversea, c), reverseb)

print('матрица x:')
print(x)
# Out:
# матрица x:
# [[ 1.00000000e+00  1.11022302e-15]
#  [-2.00000000e+00  1.00000000e+00]
#  [ 3.00000000e+00 -4.00000000e+00]]

# %% [markdown]
# ## Лабораторная работа №1

# %% [markdown]
# Замечание: при решении данных задач не подразумевается использования циклов или генераторов Python, если в задании не сказано обратного. Решение должно опираться на использования функционала библиотеки `numpy`.

# %%
import numpy as np

# %% [markdown]
# 1. Файл `minutes_n_ingredients.csv` содержит информацию об идентификаторе рецепта, времени его выполнения в минутах и количестве необходимых ингредиентов. Считайте данные из этого файла в виде массива `numpy` типа `int32`, используя `np.loadtxt`. Выведите на экран первые 5 строк массива.

# %%
data = np.loadtxt('minutes_n_ingredients.csv', delimiter=',', dtype=np.int32, skiprows=1)

print(data[:5])
# Out:
# [[127244     60     16]
#  [ 23891     25      7]
#  [ 94746     10      6]
#  [ 67660      5      6]
#  [157911     60     14]]

# %% [markdown]
# 2. Вычислите среднее значение, минимум, максимум и медиану по каждому из столбцов, кроме первого.

# %%
avg_value2 = np.average(data[:,1], axis=0)
avg_value3 = np.average(data[:,2], axis=0)
min_value2 = np.min(data[:,1], axis=0)
min_value3 = np.min(data[:,2], axis=0)
max_value2 = np.max(data[:,1], axis=0)
max_value3 = np.max(data[:,2], axis=0)
med_value2 = np.median(data[:,1], axis=0)
med_value3 = np.median(data[:,1], axis=0)

print(f"Ср. зн. 2 столбца: {avg_value2}")
print(f"Ср. зн. 3 столбца: {avg_value3}")
print(f"Мин. зн. 2 столбца: {min_value2}")
print(f"Мин. зн. 3 столбца: {min_value3}")
print(f"Макс. зн. 2 столбца: {max_value2}")
print(f"Макс. зн. 3 столбца: {max_value3}")
print(f"Медиана 2 столбца: {med_value2}")
print(f"Медиана 3 столбца: {med_value3}")
# Out:
# Ср. зн. 2 столбца: 21601.00169
# Ср. зн. 3 столбца: 9.05528
# Мин. зн. 2 столбца: 0
# Мин. зн. 3 столбца: 1
# Макс. зн. 2 столбца: 2147483647
# Макс. зн. 3 столбца: 39
# Медиана 2 столбца: 40.0
# Медиана 3 столбца: 40.0

# %% [markdown]
# 3. Ограничьте сверху значения продолжительности выполнения рецепта значением квантиля $q_{0.75}$.

# %%
# Импортирование библиотеки NumPy
import numpy as np

# Вычисление 75-го квантиля (третьего квартиля) для второго столбца в массиве данных
quantile_75 = np.quantile(data[:, 1], 0.75)

# Фильтрация данных: выбор строк, где значения второго столбца не превышают 75-й квантиль
# Функция np.where() используется для нахождения индексов строк, удовлетворяющих условию
# Затем эти индексы используются для выбора соответствующих строк из исходного массива данных
# Результат сохраняется в новой переменной new_data
new_data = data[np.where(data[:, 1] <= quantile_75)[0], :]

# Вывод нового массива данных и его формы (количества строк и столбцов)
print(new_data, new_data.shape)
# Out:
# [[127244     60     16]
#  [ 23891     25      7]
#  [ 94746     10      6]
#  ...
#  [ 43407     35      7]
#  [498432     65     15]
#  [370915      5      4]] (75461, 3)

# %% [markdown]
# 4. Посчитайте, для скольких рецептов указана продолжительность, равная нулю. Замените для таких строк значение в данном столбце на 1.

# %%
data_copy = data.copy()
print(len(data_copy[data_copy[:, 1] == 0]))
data_copy[data_copy[:, 1] == 0] = 1
print(len(data_copy[data_copy[:, 1] == 0]))
# Out:
# 479
# 0

# %% [markdown]
# 5. Посчитайте, сколько уникальных рецептов находится в датасете.

# %%
# Выбор всех значений второго столбца и всех столбцов, начиная с третьего, из массива данных
# Функция np.unique() используется для нахождения уникальных значений в этом подмассиве
# Длина этого массива уникальных значений дает количество уникальных комбинаций столбцов, начиная со второго
# Это количество выводится на экран
print(len(np.unique(data[:, 1:])))
# Out:
# 656

# %% [markdown]
# 6. Сколько и каких различных значений кол-ва ингредиентов присутвует в рецептах из датасета?

# %%
# Вызов функции np.unique() для нахождения уникальных значений второго столбца массива данных
# Аргумент return_counts=True указывает функции возвращать количество вхождений каждого уникального элемента
data6, count = np.unique(data[:, 2], return_counts=True)

# Итерация по парам значений (уникальное значение, количество вхождений) с помощью функции zip()
# В каждой итерации переменная i будет содержать уникальное значение, а переменная j - количество вхождений этого значения
for i, j in zip(data6, count):
    # Вывод на экран информации о количестве вхождений каждого уникального значения
    # Используется форматированная строка (f-string) для вывода переменных i и j
    print(f"Кол-во ингридиентов-{i}, встретилось {j} раз")
# Out:
# Кол-во ингридиентов-1, встретилось 13 раз
# Кол-во ингридиентов-2, встретилось 926 раз
# Кол-во ингридиентов-3, встретилось 2895 раз
# Кол-во ингридиентов-4, встретилось 5515 раз
# Кол-во ингридиентов-5, встретилось 7913 раз
# Кол-во ингридиентов-6, встретилось 9376 раз
# Кол-во ингридиентов-7, встретилось 10628 раз
# Кол-во ингридиентов-8, встретилось 10951 раз
# Кол-во ингридиентов-9, встретилось 10585 раз
# Кол-во ингридиентов-10, встретилось 9591 раз
# Кол-во ингридиентов-11, встретилось 8297 раз
# Кол-во ингридиентов-12, встретилось 6605 раз
# Кол-во ингридиентов-13, встретилось 4997 раз
# Кол-во ингридиентов-14, встретилось 3663 раз
# Кол-во ингридиентов-15, встретилось 2595 раз
# Кол-во ингридиентов-16, встретилось 1767 раз
# Кол-во ингридиентов-17, встретилось 1246 раз
# Кол-во ингридиентов-18, встретилось 790 раз
# Кол-во ингридиентов-19, встретилось 573 раз
# Кол-во ингридиентов-20, встретилось 376 раз
# Кол-во ингридиентов-21, встретилось 217 раз
# ...

# %% [markdown]
# 7. Создайте версию массива, содержащую информацию только о рецептах, состоящих не более чем из 5 ингредиентов.

# %%
# Фильтрация данных: выбор строк, где значения второго столбца (количество ингредиентов) не превышают 5
# Для этого используется условие data[:, 2] <= 5, которое выбирает строки, где значение во втором столбце не больше 5
# Результат сохраняется в переменной recipes5
recipes5 = data[data[:, 2] <= 5]

# Вывод на экран переменной recipes5, содержащей только строки, где количество ингредиентов не превышает 5
recipes5
# Out:
# array([[446597,     15,      5],
#        [204134,      5,      3],
#        [ 25623,      6,      4],
#        ...,
#        [ 52088,     60,      5],
#        [128811,     15,      4],
#        [370915,      5,      4]])

# %% [markdown]
# 8. Для каждого рецепта посчитайте, сколько в среднем ингредиентов приходится на одну минуту рецепта. Найдите максимальное значение этой величины для всего датасета

# %%
# Вычисление максимального значения отношения значений третьего столбца (количество ингредиентов) к значениям первого столбца (время приготовления)
# Предварительно фильтруем значения второго столбца, чтобы исключить нули
# Функция np.where() используется для замены нулевых значений во втором столбце на значение по умолчанию (1)
# Это необходимо для избежания ошибки деления на ноль
time_column = np.where(data[:, 1] == 0, 1, data[:, 1])
max_ratio = np.max(data[:, 2] / time_column)

print("Максимальное отношение количества ингредиентов к времени приготовления:", max_ratio)

# Вычисление отношения значений третьего столбца (количество ингредиентов) к значениям первого столбца (время приготовления)
# Предварительно фильтруем значения второго столбца, чтобы избежать деления на ноль
# Вместо нулей во втором столбце мы будем использовать значение по умолчанию (1)
time_column_for_ratio = np.where(data[:, 1] == 0, 1, data[:, 1])
ingredient_time_ratio = data[:, 2] / time_column_for_ratio

print("Отношение количества ингредиентов к времени приготовления для каждого рецепта:", ingredient_time_ratio)
# Out:
# Максимальное отношение количества ингредиентов к времени приготовления: 24.0
# Отношение количества ингредиентов к времени приготовления для каждого рецепта: [0.26666667 0.28       0.6        ... 0.23076923 0.8        0.1       ]

# %% [markdown]
# 9. Вычислите среднее количество ингредиентов для топ-100 рецептов с наибольшей продолжительностью

# %%
# Создание копии исходных данных, чтобы избежать изменения оригинального массива
data9 = data.copy()

# Сортировка копии данных по второму столбцу (время приготовления) в порядке убывания
# Для этого используется метод argsort(), который возвращает индексы элементов массива, отсортированных по возрастанию
# Индексы затем инвертируются (с помощью [::-1]), чтобы получить сортировку по убыванию
sorted_data9 = data9[data9[:, 1].argsort()[::-1]]

# Выбор первых 100 строк из отсортированных данных, что соответствует топ-100 рецептам с наибольшим временем приготовления
top_100_recipes = sorted_data9[:100]

# Вычисление среднего количества ингредиентов для топ-100 рецептов
# Для этого используется функция np.average(), которая вычисляет среднее значение в массиве
avg_ingredients = np.average(top_100_recipes[:, 2])

# Вывод на экран среднего количества ингредиентов для топ-100 рецептов
print("Среднее количество ингредиентов для топ-100 рецептов:", avg_ingredients)
# Out:
# Среднее количество ингредиентов для топ-100 рецептов: 6.61

# %% [markdown]
# 10. Выберите случайным образом и выведите информацию о 10 различных рецептах

# %%
# Генерация случайных индексов для выбора случайных строк из исходного массива данных
# Функция np.random.choice() используется для генерации случайных индексов
# Аргумент len(data) указывает количество строк в массиве данных, из которого происходит выборка
# Аргумент size=10 указывает количество случайных индексов, которые нужно выбрать (в данном случае, 10)
# Аргумент replace=False указывает, что выборка должна быть без замещения, т.е. одна и та же строка не может быть выбрана более одного раза
random_indices = np.random.choice(len(data), size=10, replace=False)

# Выбор случайных строк из исходного массива данных на основе сгенерированных случайных индексов
random_recipes = data[random_indices]

# Вывод на экран информации о случайно выбранных рецептах
print("Информация о случайно выбранных рецептах:")
print(random_recipes)
# Out:
# Информация о случайно выбранных рецептах:
# [[306231     65     10]
#  [146932     23      6]
#  [347590     20     13]
#  [367308     85     16]
#  [ 23866     90      6]
#  [140000     10     12]
#  [294275     12     14]
#  [164804     25      6]
#  [356517     18      4]
#  [206084     18      8]]

# %% [markdown]
# 11. Выведите процент рецептов, кол-во ингредиентов в которых меньше среднего.

# %%
# Фильтрация данных: выбор строк, где значения второго столбца (количество ингредиентов) меньше среднего значения avg_value3
# Результат сохраняется в переменной filtered_recipes
filtered_recipes = data[data[:, 2] < avg_value3]

# Вычисление количества отфильтрованных рецептов
num_filtered_recipes = len(filtered_recipes)

# Вычисление общего количества рецептов в исходных данных
total_recipes = len(data)

# Вычисление процента отфильтрованных рецептов от общего количества рецептов
procent = (num_filtered_recipes / total_recipes) * 100

# Вывод на экран процента рецептов, количество ингредиентов в которых меньше среднего
print("Процент рецептов, количество ингредиентов в которых меньше среднего:", procent, "%")
# Out:
# Процент рецептов, количество ингредиентов в которых меньше среднего: 58.802 %

# %% [markdown]
# 12. Назовем "простым" такой рецепт, длительность выполнения которого не больше 20 минут и кол-во ингредиентов в котором не больше 5. Создайте версию датасета с дополнительным столбцом, значениями которого являются 1, если рецепт простой, и 0 в противном случае.

# %%
# Создание нового массива good_recepts, заполненного нулями, с размерностью (количество строк в исходном массиве данных, 4)
# Для этого используется функция np.zeros(), которая создает массив из нулей
# Аргументы (data.shape[0], 4) указывают количество строк и 4 столбца в новом массиве
# Тип данных устанавливается как целочисленный (dtype=int)
good_recepts = np.zeros((data.shape[0], 4), dtype=int)

# Копирование первых трех столбцов исходного массива данных в новый массив good_recepts
# Это делается с помощью среза [:, :3], который выбирает все строки и первые три столбца
good_recepts[:, :3] = data

# Использование индексации с помощью np.where() для определения индексов строк, где количество ингредиентов (столбец 3) не превышает 5 и время приготовления (столбец 2) не превышает 20 минут
# Условие ((data[:, 2] <= 5) & (data[:, 1] <= 20)) создает маску, указывающую на строки, где выполняются оба условия
# Функция np.where() возвращает индексы строк, удовлетворяющих этой маске
# Далее, этим индексам соответствующим строкам в четвертом столбце (индекс 3) нового массива присваивается значение 1
good_recepts[np.where(((data[:, 2] <= 5) & (data[:, 1] <= 20))), 3] = 1

# Вывод на экран нового массива good_recepts
good_recepts
# Out:
# array([[127244,     60,     16,      0],
#        [ 23891,     25,      7,      0],
#        [ 94746,     10,      6,      0],
#        ...,
#        [498432,     65,     15,      0],
#        [370915,      5,      4,      1],
#        [ 81993,    140,     14,      0]])

# %% [markdown]
# 13. Выведите процент "простых" рецептов в датасете

# %%
# Создание нового массива new_data размером (3, max_len, 3), где 3 - количество категорий, max_len - максимальная длина рецептов в каждой категории, 3 - количество столбцов в каждом рецепте
# Все значения в новом массиве инициализируются нулями
new_data = np.zeros((3, max_len, 3), dtype=int)

# Заполнение нового массива new_data данными из категорий коротких, стандартных и длинных рецептов
# Каждая категория рецептов занимает один из трех "уровней" нового массива
# Срезы short[:max_len], standart[:max_len], long[:max_len] обеспечивают, что каждая категория содержит не более max_len рецептов
new_data[0, :max_len, :] = short[:max_len]
new_data[1, :max_len, :] = standart[:max_len]
new_data[2, :max_len, :] = long[:max_len]

new_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Создание нового массива new_data размером (3, max_len, 3), где 3 - количество категорий, max_len - максимальная длина рецептов в каждой категории, 3 - количество столбцов в каждом рецепте
#       2 # Все значения в новом массиве инициализируются нулями
# ----> 3 new_data = np.zeros((3, max_len, 3), dtype=int)
#       5 # Заполнение нового массива new_data данными из категорий коротких, стандартных и длинных рецептов
#       6 # Каждая категория рецептов занимает один из трех "уровней" нового массива
#       7 # Срезы short[:max_len], standart[:max_len], long[:max_len] обеспечивают, что каждая категория содержит не более max_len рецептов
#       8 new_data[0, :max_len, :] = short[:max_len]
#
# NameError: name 'max_len' is not defined

# %% [markdown]
# 14. Разделим рецепты на группы по следующему правилу. Назовем рецепты короткими, если их продолжительность составляет менее 10 минут; стандартными, если их продолжительность составляет более 10, но менее 20 минут; и длинными, если их продолжительность составляет не менее 20 минут. Создайте трехмерный массив, где нулевая ось отвечает за номер группы (короткий, стандартный или длинный рецепт), первая ось - за сам рецепт и вторая ось - за характеристики рецепта. Выберите максимальное количество рецептов из каждой группы таким образом, чтобы было возможно сформировать трехмерный массив. Выведите форму полученного массива.

# %%
# Фильтрация данных на три категории: "короткие", "стандартные" и "длинные" рецепты, в зависимости от времени приготовления
# "Короткие" рецепты - менее 10 минут, "стандартные" - от 10 до 19 минут, "длинные" - 20 минут и более
# Это делается путем использования условий в срезах массива данных data
short = data[data[:, 1] < 10]
standart = data[(data[:, 1] >= 10) & (data[:, 1] < 20)]
long = data[data[:, 1] >= 20]

# Вывод на экран данных о категоризации рецептов
# short содержит короткие рецепты, standart - стандартные, long - длинные
short, standart, long

# Вычисление максимальной длины рецептов среди коротких, стандартных и длинных
# Это позволит создать новый массив new_data с одинаковым числом рецептов в каждой категории
max_len = min(len(short), len(standart), len(long))

# Создание нового массива new_data размером (3, max_len, 3), где 3 - количество категорий, max_len - максимальная длина рецептов в каждой категории, 3 - количество столбцов в каждом рецепте
# Все значения в новом массиве инициализируются нулями
new_data = np.zeros((3, max_len, 3), dtype=int)

# Заполнение нового массива new_data данными из категорий коротких, стандартных и длинных рецептов
# Каждая категория рецептов занимает один из трех "уровней" нового массива
# Срезы short[:max_len], standart[:max_len], long[:max_len] обеспечивают, что каждая категория содержит не более max_len рецептов
new_data[0, :max_len, :] = short[:max_len]
new_data[1, :max_len, :] = standart[:max_len]
new_data[2, :max_len, :] = long[:max_len]
new_data
